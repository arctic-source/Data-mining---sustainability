# %% [markdown]
# ![sam-bark-R1GWSOJ9cng-unsplash 2.jpg](attachment:27680988-b1cd-4ffa-aa9f-eedcc46a778a.jpg)
# # Data mining project - answers to sustainability questions

# %% [markdown]
# This is a personal project dedicated to data mining. I decided to select a project in a domain that interests me to learn more about the domain - which is sustainability. At the same time, the project allows me to practice work with complex, real-world datasets and machine learning.

# %% [markdown]
# -----------------
# ## Project structure
#
# 0. Data mining
# 1. Research questions
# 2. Data sources
# 3. Prerequisities
# 4. Project notebooks

# %% [markdown]
# ---------------
# ## Tools used
# In the project, I will use Python to process and model data, along with common data science libraries such as numpy, pandas, scikit-learn, tensorflow, statsmodels and jupyter notebook.

# %% [markdown]
# ------------------
# ## 0 - Data mining
# **Definition: Data mining is "the non-trivial process of identifying valid, novel, potentially useful, and ultimately understandable patterns in data"** [[Kriegel, 2007]](https://link.springer.com/article/10.1007/s10618-007-0067-9).
#
# I find this an important skill for the age I live in. I think an ability to extract and identify trends and patterns in data can be a useful skill and can provide one with important information for decision making. A data mining project should also have an aim since just looking through data does not neccessarily generate useful information about patterns in the data. Also, the identification of useful information or patterns is required from definition. Therefore, I will formulate some domain-ispecific data mining research questions, even though I do not have much formal knowledge in this aspect yet.

# %% [markdown]
# ------------------
# ## 1 - Research questions

# %% [markdown]
# Here are some initial research questions that I will aim to answer a beginner in the domain:
#
# **1. In the present, which countries are the biggest CO2 producers on the planet? And which are the biggest CO2 producers per capita?
# 2. Can we build a machine learning model to predict the amount of CO2 that is generated by a country, given other data about the country?
# 3. Analyze the time series of yearly CO2 production that is being generated by the 5 biggest producers of CO2 in the world. What can we learn from this analysis?**

# %% [markdown]
# ------------------
# ## 2 - Data sources

# %% [markdown]
# To answer the questions, a suitable data source is needed. For this cause, I selected the [The World Bank](https://databank.worldbank.org/source/sustainable-development-goals-(sdgs)). The bank includes a dataset named "Sustainable Development Goals (SDGs)" which I identified as containing relevant features. I will refer to this dataset as the **SDG dataset**. Next, I selected a few options for data export - I selected all countries available and all features available. The dataset includes a high number of features ranging from education (literacy rate, primary education completion rate), economy (GDP, exports, unemployment, foreign investments, taxes) to environment (species threatened, CO2 emissions). Next, I specified I want to download this information about the following time range: 2010-2020 (to answer the first question) and 1990-2020 (to answer the third question). Here is the UI for data selection:

# %% [markdown]
# <div>
# <img src="attachment:1d73e57a-f84e-4f5e-8c91-df0367bfc28c.PNG" width="500"/>
# </div>

# %% [markdown]
# I also use another dataset as a supplement to the main SDG dataset mentioned in answering the first question. The supplementary dataset is the ["Population Estimates and Projections"](https://databank.worldbank.org/source/population-estimates-and-projections) dataset, also by The World Data Bank.

# %% [markdown]
# ------------------
# ## 3 - Prerequisities

# %% [markdown]
# I should mention that I am using Python 3.11 on my local machine (Windows 10) with a virtual environment that includes some of the typical data science libraries:
# - pandas
# - numpy
# - matplotlib
# - scikit-learn
# - tensorflow
# - statsmodels
# - openpyxl - to work with MS Excel files with .xlsx suffix
#
# In the following cell, these libraries are batch installed.

# %%
# install libraries using pip, exclamation mark symbol executes the code in python terminal
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tensorflow
# !pip install statsmodels
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: tensorflow in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.11)
# Requirement already satisfied: libclang>=13.0.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.2)
# Requirement already satisfied: setuptools in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.5.1)
# Requirement already satisfied: six>=1.12.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.1.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.19.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: urllib3<2.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Requirement already satisfied: statsmodels in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy>=1.18 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from statsmodels) (2.0.2)
# Requirement already satisfied: patsy>=0.5.2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: openpyxl in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in d:\documents\python projects\2023-06-01 sustainability - data mining\python\venv\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# ------------------
# ## 4 - Project notebooks

# %% [markdown]
# Next, the project is branched into separate jupyter notebooks depending on the research question for transparency. Feel free to click on the research question of interest to explore the relevant jupyter notebook.

# %% [markdown]
# [[1] In the present, which countries are the biggest CO2 producers on the planet? And which are the biggest CO2 producers per capita?](https://github.com/arctic-source/Data-mining---sustainability/blob/main/question1.ipynb)
# [2] Can we create a machine learning model to predict the amount of CO2 that is generated by a country, given other data about the country?] [Work in progress ...]
# [[3] Analyze the time series of yearly CO2 production that is being generated by the 5 biggest producers of CO2 in the world. What can we learn from this analysis?](https://github.com/arctic-source/Data-mining---sustainability/blob/main/question3.ipynb)

# %% [markdown]
# ![tim-mossholder-qq-8dpdlBsY-unsplash 2.jpg](attachment:e77921da-f762-40d0-885f-ebf2d7f6dbc7.jpg)
